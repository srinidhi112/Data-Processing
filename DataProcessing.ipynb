# %%
import json

# %%
import pandas as pd

# %%
pd.read_json('playlist.json')
# Out:
#                         id      title  danceability  energy  key  loudness  \
# 0   5vYA1mW9g2Coh1HUFUSmlb        3AM         0.521   0.673    8    -8.685
# 1   2klCjJcucgGQysgH170npL    4 Walls         0.735   0.849    4    -4.308
# 2   093PI3mdUvOSlvMYDwnV1e      11:11         0.445   0.528   10    -7.243
# 3   64yrDBpcdwEdNY9loyEGbX    21 Guns         0.268   0.742    5    -4.939
# 4   2jiI8bNSDu7UxTtDCOqh3L         21         0.680   0.724    6    -5.633
# ..                     ...        ...           ...     ...  ...       ...
# 95  7BKLCZ1jbUBVqRi2FVlTVw     Closer         0.748   0.524    8    -5.599
# 96  31qa3MvGhA4FbbeUOhBe4J      cocoa         0.572   0.341   11   -11.924
# 97  0nKpHGrnuejevp6openGaF       Cold         0.648   0.734    0    -6.289
# 98  7qKPyKGfnYRdcpnc1Wz97A  Cold Feet         0.582   0.719    5    -8.884
# 99  2Nbk6e3lExNzZj9AuCwV8C  Cold Skin         0.393   0.695    7    -6.887
#
# ...

# %%
json_data=pd.read_json('playlist.json')

# %%
json_data
# Out:
#                         id      title  danceability  energy  key  loudness  \
# 0   5vYA1mW9g2Coh1HUFUSmlb        3AM         0.521   0.673    8    -8.685
# 1   2klCjJcucgGQysgH170npL    4 Walls         0.735   0.849    4    -4.308
# 2   093PI3mdUvOSlvMYDwnV1e      11:11         0.445   0.528   10    -7.243
# 3   64yrDBpcdwEdNY9loyEGbX    21 Guns         0.268   0.742    5    -4.939
# 4   2jiI8bNSDu7UxTtDCOqh3L         21         0.680   0.724    6    -5.633
# ..                     ...        ...           ...     ...  ...       ...
# 95  7BKLCZ1jbUBVqRi2FVlTVw     Closer         0.748   0.524    8    -5.599
# 96  31qa3MvGhA4FbbeUOhBe4J      cocoa         0.572   0.341   11   -11.924
# 97  0nKpHGrnuejevp6openGaF       Cold         0.648   0.734    0    -6.289
# 98  7qKPyKGfnYRdcpnc1Wz97A  Cold Feet         0.582   0.719    5    -8.884
# 99  2Nbk6e3lExNzZj9AuCwV8C  Cold Skin         0.393   0.695    7    -6.887
#
# ...

# %%
type(json_data)
# Out:
# pandas.core.frame.DataFrame

# %%
json_data.to_excel('output_data.xlsx')
